# %%
# Global normalisation based on calculated 2.5% and 97.5% percentile values calculated in Matlab
import arcpy
for x in range(0,3):
   if x == 0:
        Infile = "ORLDAACGrazingClip.tif"
        OutfileNorm = r"D:\Data\Dropbox\Lactuca\Temp\ORL_DAACGrazingNormalised.tif"
        OutfileZeros = r"D:\Data\Dropbox\Lactuca\Temp\ORL_DAACGrazingZeros.tif"
        ValueMin = 0
        ValueMax = 298.9332886
   elif x == 1:
        Infile = "NoonCIGrazingClip.tif"
        OutfileNorm = r"D:\Data\Dropbox\Lactuca\Temp\NoonCIGrazingNormalised.tif"
        OutfileZeros = r"D:\Data\Dropbox\Lactuca\Temp\NoonCIGrazingZeros.tif"
        ValueMin = 0
        ValueMax = 108.0643311
   elif x == 2:
        Infile = "AvitabileGrazingClip.tif"
        OutfileNorm = r"D:\Data\Dropbox\Lactuca\Temp\AvitabileGrazingNormalised.tif"
        OutfileZeros = r"D:\Data\Dropbox\Lactuca\Temp\AvitabileGrazingZeros.tif"
        ValueMin = 0
        ValueMax = 78.67592621
   else:
        print("This code stops")
   with arcpy.EnvManager(overwriteOutput=True):
        out_raster = arcpy.sa.Minus(Infile, ValueMin); out_raster.save("TmpLayer1")
        out_raster = arcpy.sa.Con("TmpLayer1", 0, " TmpLayer1", "VALUE < 0")
        out_raster.save("TmpLayer2")
        out_raster = arcpy.sa.Divide("TmpLayer2", ValueMax); out_raster.save("TmpLayer3")
        out_raster = arcpy.sa.Con("TmpLayer3", 1, " TmpLayer3", "VALUE > 1")
        out_raster.save(OutfileNorm)
        out_raster = arcpy.sa.IsNull(OutfileNorm); out_raster.save("TmpLayer4")   
        out_raster = arcpy.sa.Con("TmpLayer4", "LandExtentasZeros.tif", OutfileNorm,"Value = 1")
        out_raster.save(OutfileZeros)

# %%
with arcpy.EnvManager(cellSize= 0.001):
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "CNGrazingNormalised.tif", "ZonalSt_CNGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "LPJGrazingNormalised.tif", "ZonalSt_LPJGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "FAOGrazingNormalised.tif", "ZonalSt_FAOGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "GilbertGrazingNormalised.tif", "ZonalSt_GilbertGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "ScholesGrazingNormalised.tif", "ZonalSt_ScholesGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "AriesGrazingNormalised.tif", "ZonalSt_AriesGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "InVestGrazingNormalised.tif", "ZonalSt_InVestGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "TEEBGrazingNormalised.tif", "ZonalSt_TEEBGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "KindermannGrazingNormalised.tif", "ZonalSt_KindermannGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "NoonCIGrazingNormalised.tif", "ZonalSt_NoonCIGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "ORL_DAACGrazingNormalised.tif", "ZonalSt_ORLDAACGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "AvitabileGrazingNormalised.tif", "ZonalSt_AvitabileGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "Mean_GrazingEnsemble.tif", "ZonalSt_MeanGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "Median_GrazingEnsemble.tif", "ZonalSt_MedianGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "PCA_GrazingEnsemble.tif", "ZonalSt_PCAGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "CorCoef_GrazingEnsemble.tif", "ZonalSt_CorCoefGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "R2Median_GrazingEnsemble.tif", "ZonalSt_R2MedianGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "LeaveOneOut_GrazingEnsemble.tif", "ZonalSt_LeaveOneOutGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "Grid_GrazingEnsemble.tif", "ZonalSt_GridGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")
    arcpy.sa.ZonalStatisticsAsTable("Gaul_2_Countries", "OBJECTID", "SemAmongModels_Grazing.tif", "ZonalSt_SEMGrazing", "DATA", "ALL", "CURRENT_SLICE", [90], "AUTO_DETECT")

# %%
# ARCMAP CODES for Normalisation
# Global normalisation based on calculated 2.5% and 97.5% percentile values calculated in Matlab
import arcpy
from arcpy.sa import *
with arcpy.EnvManager(overwriteOutput=True):
     #Aries
    outCon = Con((Raster("AriesGrazingClip.tif")/8896.5) > 1,1, (Raster("AriesGrazingClip.tif")/8896.5))
    outCon.save("outcon")
    Con2 = Con(IsNull(Raster("outcon"))==1, Raster("LandExtentasZeros.tif"), Raster("outcon"))
    outCon.save("AriesNormalisedCheck")
    Con2.save("AriesZerosCheck")
    #CN
    outCon = Con((Raster("CNGilbertClip.tif")/0.6940165) > 1,1, (Raster("CNGilbertClip.tif")/0.6940165))
    outCon.save("outcon")
    Con2 = Con(IsNull(Raster("outcon"))==1, Raster("LandExtentasZeros.tif"), Raster("outcon"))
    outCon.save("CNormalisedCheck")
    Con2.save("CNZerosCheck")
     #FAO
    outCon = Con((Raster("FAOLSUClip.tif")/89.95945) > 1,1, (Raster("FAOLSUClip.tif")/89.95945))
    outCon.save("outcon")
    Con2 = Con(IsNull(Raster("outcon"))==1, Raster("LandExtentasZeros.tif"), Raster("outcon"))
    outCon.save("FAONormalisedCheck")
    Con2.save("FAOZerosCheck")
    #Gilbert
    outCon = Con((Raster("GilbertLSUClip.tif")/6919.483) > 1,1, (Raster("GilbertLSUClip.tif")/6919.483))
    outCon.save("outcon")
    Con2 = Con(IsNull(Raster("outcon"))==1, Raster("LandExtentasZeros.tif"), Raster("outcon"))
    outCon.save("GilbertNormalisedCheck")
    Con2.save("GilbertZerosCheck")
    #Harris
    outCon = Con((Raster("HarrisGrazingClip.tif")/89.10565575) > 1,1, (Raster("HarrisGrazingClip.tif")/89.10565575))
    outCon.save("outcon")
    Con2 = Con(IsNull(Raster("outcon"))==1, Raster("LandExtentasZeros.tif"), Raster("outcon"))
    outCon.save("HarrisNormalisedCheck")
    Con2.save("HarrisZerosCheck")
    #InVest
    outCon = Con((Raster("InVestGrazingClip.tif")/19.96301625) > 1,1, (Raster("InVestGrazingClip.tif")/19.96301625))
    outCon.save("outcon")
    Con2 = Con(IsNull(Raster("outcon"))==1, Raster("LandExtentasZeros.tif"), Raster("outcon"))
    outCon.save("InVestNormalisedCheck")
    Con2.save("InVestZerosCheck")
    #Kindermann
    outCon = Con((Raster("KindermannGrazingClip.tif")/70) > 1,1, (Raster("KindermannGrazingClip.tif")/70))
    outCon.save("outcon")
    Con2 = Con(IsNull(Raster("outcon"))==1, Raster("LandExtentasZeros.tif"), Raster("outcon"))
    outCon.save("KindermannNormalisedCheck")
    Con2.save("KindermannZerosCheck")
    #LPJGrass
    outCon = Con((Raster("LPJGrassClip.tif")/0.639) > 1,1, (Raster("LPJGrassClip.tif")/0.639))
    outCon.save("outcon")
    Con2 = Con(IsNull(Raster("outcon"))==1, Raster("LandExtentasZeros.tif"), Raster("outcon"))
    outCon.save("LPJNormalisedCheck")
    Con2.save("LPJGrassZerosCheck")
    #ScholesSolar
    outCon = Con((Raster("ScholesSolarClip.tif")/3.613599) > 1,1, (Raster("ScholesSolarClip.tif")/3.613599))
    outCon.save("outcon")
    Con2 = Con(IsNull(Raster("outcon"))==1, Raster("LandExtentasZeros.tif"), Raster("outcon"))
    outCon.save("SolarNormalisedCheck")
    Con2.save("ScholesSolarZerosCheck")
    #TEEB
    outCon = Con((Raster("TEEBGrazingClip.tif")/181) > 1,1, (Raster("TEEBGrazingClip.tif")/181))
    outCon.save("outcon")
    Con2 = Con(IsNull(Raster("outcon"))==1, Raster("LandExtentasZeros.tif"), Raster("outcon"))
    outCon.save("TEEBNormalisedCheck")
    Con2.save("TEEBZerosCheck")
